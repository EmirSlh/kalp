# %%
import pandas as pd

# %%
dataset=pd.read_csv('ForestDataSet.csv')

# %%
dataset
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 0     63         1         3         145        233          1    0      150
# 1     37         1         2         130        250          0    1      187
# 2     41         0         1         130        204          0    0      172
# 3     56         1         1         120        236          0    1      178
# 4     57         0         0         120        354          0    1      163
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 375   58         1         1         120        284          0    0      160
# 376   20         1         0         150        151          0    0      115
# 377   43         1         0         150        247          0    1      171
# 378   43         1         0         150        247          0    1      171
# 379   49         1         0         150        247          0    1      171
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   yas         380 non-null    int64
#  1   cinsiyet    380 non-null    int64
#  2   agriTipi    380 non-null    int64
#  3   kanBasinci  380 non-null    int64
#  4   kolestrol   380 non-null    int64
#  5   kanSekeri   380 non-null    int64
#  6   ekg         380 non-null    int64
#  7   thalach     380 non-null    int64
#  8   angina      380 non-null    int64
#  9   eskiSt      380 non-null    float64
#  10  yeniSt      380 non-null    int64
#  11  floroskopi  380 non-null    int64
#  12  thal        380 non-null    int64
#  13  target      380 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 41.7 KB

# %%
dataset.isnull().sum()
# Out:
# yas           0
# cinsiyet      0
# agriTipi      0
# kanBasinci    0
# kolestrol     0
# kanSekeri     0
# ekg           0
# thalach       0
# angina        0
# eskiSt        0
# yeniSt        0
# floroskopi    0
# thal          0
# target        0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['yas', 'cinsiyet', 'agriTipi', 'kanBasinci', 'kolestrol', 'kanSekeri',
#        'ekg', 'thalach', 'angina', 'eskiSt', 'yeniSt', 'floroskopi', 'thal',
#        'target'],
#       dtype='object')

# %%
y=dataset['target']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 375    0
# 376    1
# 377    1
# 378    1
# 379    1
# Name: target, Length: 380, dtype: int64

# %%
x = dataset[['yas','cinsiyet','agriTipi','kanBasinci','kolestrol','kanSekeri','ekg','thalach','angina','eskiSt','yeniSt','floroskopi','thal']]

# %%
x
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 0     63         1         3         145        233          1    0      150
# 1     37         1         2         130        250          0    1      187
# 2     41         0         1         130        204          0    0      172
# 3     56         1         1         120        236          0    1      178
# 4     57         0         0         120        354          0    1      163
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 375   58         1         1         120        284          0    0      160
# 376   20         1         0         150        151          0    0      115
# 377   43         1         0         150        247          0    1      171
# 378   43         1         0         150        247          0    1      171
# 379   49         1         0         150        247          0    1      171
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x_train.shape,x_test.shape,x.shape)
# Out:
# (304, 13) (76, 13) (380, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model
# Out:
# RandomForestClassifier()

# %%
x_train
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 143   67         0         0         106        223          0    1      142
# 328  121         0         1         130        236          0    0      174
# 150   66         1         0         160        228          0    0      138
# 336  113         0         1         130        236          0    0      174
# 10    54         1         0         140        239          0    1      160
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 181   65         0         0         150        225          0    0      114
# 7     44         1         1         120        263          0    1      173
# 38    65         0         2         155        269          0    1      148
# 67    45         0         1         130        234          0    0      175
# 131   49         0         1         134        271          0    1      162
#
# ...

# %%
y_train
# Out:
# 143    1
# 328    1
# 150    1
# 336    1
# 10     1
#       ..
# 181    0
# 7      1
# 38     1
# 67     1
# 131    1
# Name: target, Length: 304, dtype: int64

# %%
rf_model.fit(x_train, y_train)
rf_train_prediction = rf_model.predict(x_train)
rf_test_prediction = rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
rf_training_data_accuracy = accuracy_score(rf_train_prediction, y_train)
rf_test_data_accuracy = accuracy_score(rf_test_prediction, y_test)
print("Random Forest Model doğruluk oranı:", rf_training_data_accuracy)
print("Random Forest Model doğruluk oranı:", rf_test_data_accuracy)
# Out:
# Random Forest Model doğruluk oranı: 1.0
# Random Forest Model doğruluk oranı: 0.8157894736842105

# %%
import pickle

# %%
with open('model.pkl','wb') as files:
    pickle.dump(rf_model,files)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='yas', bins=20, kde=True)
plt.title('Yaş Dağılımı')
plt.xlabel('Yaş')
plt.ylabel('Frekans')
plt.savefig('yas_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='kanBasinci', bins=20, kde=True)
plt.title('Kan Basıncı Dağılımı')
plt.xlabel('kanBasinci')
plt.ylabel('Frekans')
plt.savefig('basinc_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='kolestrol', bins=20, kde=True)
plt.title('Kolestrol Dağılımı')
plt.xlabel('kolestrol')
plt.ylabel('Frekans')
plt.savefig('kolestrol_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='thalach', bins=20, kde=True)
plt.title('thalach Dağılımı')
plt.xlabel('thalach')
plt.ylabel('Frekans')
plt.savefig('thalach_dagilimi.png')
plt.show()
