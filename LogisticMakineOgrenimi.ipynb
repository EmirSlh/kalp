# %%
import pandas as pd

# %%
dataset=pd.read_csv('LogisticDataSet.csv')

# %%
dataset
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 0     63         1         3         145        233          1    0      150
# 1     37         1         2         130        250          0    1      187
# 2     41         0         1         130        204          0    0      172
# 3     56         1         1         120        236          0    1      178
# 4     57         0         0         120        354          0    1      163
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 388   58         1         1         120        284          0    0      160
# 389   20         1         0         150        151          0    0      115
# 390   43         1         0         150        247          0    1      171
# 391   43         1         0         150        247          0    1      171
# 392   49         1         0         150        247          0    1      171
#
#      angina  eskiSt  yeniSt  floroskopi  thal  target
# 0         0     2.3       0           0     1       1
# 1         0     3.5       0           0     2       1
# 2         0     1.4       2           0     2       1
# 3         0     0.8       2           0     2       1
# 4         1     0.6       2           0     2       1
# ..      ...     ...     ...         ...   ...     ...
# 388       0     3.0       1           0     2       0
# 389       0     1.0       0           0     0       1
# 390       0     1.0       2           0     2       1
# 391       0     1.0       2           0     2       1
# 392       0     1.0       2           0     2       1
#
# [393 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   yas         393 non-null    int64
#  1   cinsiyet    393 non-null    int64
#  2   agriTipi    393 non-null    int64
#  3   kanBasinci  393 non-null    int64
#  4   kolestrol   393 non-null    int64
#  5   kanSekeri   393 non-null    int64
#  6   ekg         393 non-null    int64
#  7   thalach     393 non-null    int64
#  8   angina      393 non-null    int64
#  9   eskiSt      393 non-null    float64
#  10  yeniSt      393 non-null    int64
#  11  floroskopi  393 non-null    int64
#  12  thal        393 non-null    int64
#  13  target      393 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 43.1 KB

# %%
dataset.isnull().sum()
# Out:
# yas           0
# cinsiyet      0
# agriTipi      0
# kanBasinci    0
# kolestrol     0
# kanSekeri     0
# ekg           0
# thalach       0
# angina        0
# eskiSt        0
# yeniSt        0
# floroskopi    0
# thal          0
# target        0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['yas', 'cinsiyet', 'agriTipi', 'kanBasinci', 'kolestrol', 'kanSekeri',
#        'ekg', 'thalach', 'angina', 'eskiSt', 'yeniSt', 'floroskopi', 'thal',
#        'target'],
#       dtype='object')

# %%
y=dataset['target']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 388    0
# 389    1
# 390    1
# 391    1
# 392    1
# Name: target, Length: 393, dtype: int64

# %%
x = dataset[['yas','cinsiyet','agriTipi','kanBasinci','kolestrol','kanSekeri','ekg','thalach','angina','eskiSt','yeniSt','floroskopi','thal']]

# %%
x
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 0     63         1         3         145        233          1    0      150
# 1     37         1         2         130        250          0    1      187
# 2     41         0         1         130        204          0    0      172
# 3     56         1         1         120        236          0    1      178
# 4     57         0         0         120        354          0    1      163
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 388   58         1         1         120        284          0    0      160
# 389   20         1         0         150        151          0    0      115
# 390   43         1         0         150        247          0    1      171
# 391   43         1         0         150        247          0    1      171
# 392   49         1         0         150        247          0    1      171
#
#      angina  eskiSt  yeniSt  floroskopi  thal
# 0         0     2.3       0           0     1
# 1         0     3.5       0           0     2
# 2         0     1.4       2           0     2
# 3         0     0.8       2           0     2
# 4         1     0.6       2           0     2
# ..      ...     ...     ...         ...   ...
# 388       0     3.0       1           0     2
# 389       0     1.0       0           0     0
# 390       0     1.0       2           0     2
# 391       0     1.0       2           0     2
# 392       0     1.0       2           0     2
#
# [393 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x_train.shape,x_test.shape,x.shape)
# Out:
# (314, 13) (79, 13) (393, 13)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
x_train
# Out:
#      yas  cinsiyet  agriTipi  kanBasinci  kolestrol  kanSekeri  ekg  thalach  \
# 190   51         0         0         130        305          0    1      142
# 261   52         1         0         112        230          0    1      160
# 345  111         0         1         130        236          0    0      174
# 192   54         1         0         120        188          0    1      113
# 236   58         1         0         125        300          0    0      171
# ..   ...       ...       ...         ...        ...        ...  ...      ...
# 92    52         1         2         138        223          0    1      169
# 248   54         1         1         192        283          0    0      195
# 207   60         0         0         150        258          0    0      157
# 337  119         0         1         130        236          0    0      174
# 247   66         1         1         160        246          0    1      120
#
#      angina  eskiSt  yeniSt  floroskopi  thal
# 190       1     1.2       1           0     3
# 261       0     0.0       2           1     2
# 345       0     0.0       1           1     1
# 192       0     1.4       1           1     3
# 236       0     0.0       2           2     3
# ..      ...     ...     ...         ...   ...
# 92        0     0.0       2           4     2
# 248       0     0.0       2           1     3
# 207       0     2.6       1           2     3
# 337       0     0.0       1           1     1
# 247       1     0.0       1           3     1
#
# [314 rows x 13 columns]

# %%
y_train
# Out:
# 190    0
# 261    0
# 345    1
# 192    0
# 236    0
#       ..
# 92     1
# 248    0
# 207    0
# 337    1
# 247    0
# Name: target, Length: 314, dtype: int64

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction,y_train)

# %%
print("Doğruluk oranı:",training_data_accuracy)
# Out:
# Doğruluk oranı: 0.8949044585987261

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print("Doğruluk oranı :",test_data_accuracy)
# Out:
# Doğruluk oranı : 0.8734177215189873

# %%
prep=model.predict([[57,0,0,120,354,0,1,163,1,0.6,2,0,2]])
print(prep)
# Out:
# [1]
# c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
with open('model.pkl','wb') as files:
    pickle.dump(model,files)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='yas', bins=20, kde=True)
plt.title('Yaş Dağılımı')
plt.xlabel('Yaş')
plt.ylabel('Frekans')
plt.savefig('yas_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='kanBasinci', bins=20, kde=True)
plt.title('Kan Basıncı Dağılımı')
plt.xlabel('kanBasinci')
plt.ylabel('Frekans')
plt.savefig('basinc_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='kolestrol', bins=20, kde=True)
plt.title('Kolestrol Dağılımı')
plt.xlabel('kolestrol')
plt.ylabel('Frekans')
plt.savefig('kolestrol_dagilimi.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x='thalach', bins=20, kde=True)
plt.title('thalach Dağılımı')
plt.xlabel('thalach')
plt.ylabel('Frekans')
plt.savefig('thalach_dagilimi.png')
plt.show()
